# %%
import pandas as pd
from pathlib import Path

project_root = Path.cwd()

if project_root.name == "notebooks":
    project_root = project_root.parent

data_dir = project_root / "data"

files = {
    "executive_kpis": "executive_kpis.csv",
    "monthly_trends": "monthly_trends.csv",
    "acquisition": "acquisition.csv",
    "product_funnel": "product_funnel.csv",
    "cohort_retention": "cohort_retention.csv",
    "feature_adoption": "feature_adoption.csv",
    "churn": "churn.csv",
    "revenue": "revenue.csv",
    "experiment_results": "experiment_results.csv"
}

output_file = data_dir / "flowpilot_powerbi_data.xlsx"

with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
    for sheet_name, filename in files.items():
        df = pd.read_csv(data_dir / filename)
        df.to_excel(
            writer,
            sheet_name=sheet_name,
            index=False
        )

print(f"Updated: {output_file}")
# Out:
# Updated: /Users/darrenbarkins/Documents/GitHub/flowpilot-saas-growth-retention-analytics/data/flowpilot_powerbi_data.xlsx
